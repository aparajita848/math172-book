# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(t_sol,x_total,linestyle='--', color = 'red',label='RK2')
plt.plot(t_sol,x_total_rk4,linestyle='--', color = 'black',label='RK4')
plt.plot(t_sol,x_total_e,linestyle='--', color = 'blue',label='Euler')
# plt.plot(t_sol,x_sol_0_rk4, color = 'g',label='CSCs')
# plt.plot(t_sol,x_sol_1_rk4, color = 'b', label='P1Cs')
# plt.plot(t_sol,x_sol_2_rk4, color = 'r', label='P2Cs')
# plt.plot(t_sol,x_sol_3_rk4, color = 'm', label='TDCs')
# plt.scatter(t_data,data1_total_cells, color = 'black',label='Total cells - Data1')
# plt.scatter(t_data,data1_x0, color = 'g',label='CSCs - Data1')
# plt.scatter(t_data,data1_x1, color = 'b', label='P1Cs - Data1')
# plt.scatter(t_data,data1_x2, color = 'r', label='P2Cs - Data1')
# plt.scatter(t_data,data1_x3, color = 'm', label='TDCs - Data1')
plt.legend(loc="upper right")
plt.xlabel("t")
plt.ylabel("N")
#plt.title('RK4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.plot(t_sol,x_total,linestyle='--', color = 'red',label='RK2')
#       2 plt.plot(t_sol,x_total_rk4,linestyle='--', color = 'black',label='RK4')
#       3 plt.plot(t_sol,x_total_e,linestyle='--', color = 'blue',label='Euler')
#
# NameError: name 't_sol' is not defined
